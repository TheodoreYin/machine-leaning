# %%
import pandas as pd
digits_train = pd.read_csv("optdigits.tra")
digits_test = pd.read_csv("optdigits.tes")

# %%
digits_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3822 entries, 0 to 3821
# Data columns (total 65 columns):
# 0       3822 non-null int64
# 1       3822 non-null int64
# 6       3822 non-null int64
# 15      3822 non-null int64
# 12      3822 non-null int64
# 1.1     3822 non-null int64
# 0.1     3822 non-null int64
# 0.2     3822 non-null int64
# 0.3     3822 non-null int64
# 7       3822 non-null int64
# 16      3822 non-null int64
# 6.1     3822 non-null int64
# 6.2     3822 non-null int64
# 10      3822 non-null int64
# 0.4     3822 non-null int64
# 0.5     3822 non-null int64
# 0.6     3822 non-null int64
# 8       3822 non-null int64
# 16.1    3822 non-null int64
# 2       3822 non-null int64
# 0.7     3822 non-null int64
# 11      3822 non-null int64
# 2.1     3822 non-null int64
# 0.8     3822 non-null int64
# 0.9     3822 non-null int64
# 5       3822 non-null int64
# 16.2    3822 non-null int64
# 3       3822 non-null int64
# 0.10    3822 non-null int64
# 5.1     3822 non-null int64
# 7.1     3822 non-null int64
# 0.11    3822 non-null int64
# 0.12    3822 non-null int64
# 7.2     3822 non-null int64
# 13      3822 non-null int64
# 3.1     3822 non-null int64
# 0.13    3822 non-null int64
# 8.1     3822 non-null int64
# 7.3     3822 non-null int64
# 0.14    3822 non-null int64
# 0.15    3822 non-null int64
# 4       3822 non-null int64
# 12.1    3822 non-null int64
# 0.16    3822 non-null int64
# 1.2     3822 non-null int64
# 13.1    3822 non-null int64
# 5.2     3822 non-null int64
# 0.17    3822 non-null int64
# 0.18    3822 non-null int64
# 0.19    3822 non-null int64
# 14      3822 non-null int64
# 9       3822 non-null int64
# 15.1    3822 non-null int64
# 9.1     3822 non-null int64
# 0.20    3822 non-null int64
# 0.21    3822 non-null int64
# 0.22    3822 non-null int64
# 0.23    3822 non-null int64
# 6.3     3822 non-null int64
# 14.1    3822 non-null int64
# 7.4     3822 non-null int64
# 1.3     3822 non-null int64
# 0.24    3822 non-null int64
# 0.25    3822 non-null int64
# 0.26    3822 non-null int64
# dtypes: int64(65)
# memory usage: 1.9 MB

# %%
Xtrain = digits_train.iloc[:, :64]
ytrain = digits_train.iloc[:, 64]

# %%
from sklearn.decomposition import PCA
pcaesti = PCA(n_components=3)
Xtrain_pca = pcaesti.fit_transform(Xtrain)

# %%
from matplotlib import pyplot as plt
import mpl_toolkits.mplot3d
from matplotlib import cm
import numpy as np

# %matplotlib inline

# %%
fig = plt.figure()
fig2 = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax2 = [fig2.add_subplot(3, 3, i + 1, projection="3d") for i in range(9)]
concat = np.concatenate((Xtrain_pca, ytrain[:, None]), axis=1)
colors = cm.rainbow(np.linspace(0, 1, 10))
def use(i, dimention, concat):
    return [x[dimention] for x in concat if x[-1] == i]
for i in range(9):
    ax.scatter(use(i, 0, concat) ,use(i, 1, concat), use(i, 2, concat), c=colors[i])
    ax2[i].scatter(use(i, 0, concat) ,use(i, 1, concat), use(i, 2, concat), c=colors[i])
