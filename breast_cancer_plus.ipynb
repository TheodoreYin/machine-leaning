# %%
import pandas as pd
import numpy as np

# %%
feature_names = ["Sample code number", "Clump Thickness", "Uniformity of Cell Size", "Uniformity of Cell Shape", "Marginal Adhesion", "Single Epithelial Cell Size", "Bare Nuclei", "Bland Chromatin", "Normal Nucleoli", "Mitoses", "Class"]

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data")

# %%
df.columns = feature_names

# %%
df = df.apply(lambda x: pd.to_numeric(x, errors="coerce"))
df = df.apply(lambda x: x.replace(np.nan, x.mean()))
df
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# 5               1018099                1                        1
# 6               1018561                2                        1
# 7               1033078                2                        1
# 8               1033078                4                        2
# 9               1035283                1                        1
# 10              1036172                2                        1
# 11              1041801                5                        3
# 12              1043999                1                        1
# ...

# %%
df["Class"] = df["Class"].apply(lambda x: 0 if x == 2 else 1)
df
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# 5               1018099                1                        1
# 6               1018561                2                        1
# 7               1033078                2                        1
# 8               1033078                4                        2
# 9               1035283                1                        1
# 10              1036172                2                        1
# 11              1041801                5                        3
# 12              1043999                1                        1
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df.ix[:, 1:10], df.ix[:, 10], test_size=0.25, random_state=214)

# %%
Y_train.value_counts()
# Out:
# 0    345
# 1    178
# Name: Class, dtype: int64

# %%
for cn in X_test.columns:
    print(cn,"\n",X_test[cn].value_counts(), "\n")
# Out:
# Clump Thickness
#  5     36
# 1     28
# 10    21
# 3     21
# 4     18
# 2     18
# 6     13
# 8     10
# 9      5
# 7      5
# Name: Clump Thickness, dtype: int64
#
# Uniformity of Cell Size
#  1     98
# 10    23
# 5     12
# 3     10
# 2      9
# 8      8
# 6      6
# 4      5
# 7      3
# 9      1
# Name: Uniformity of Cell Size, dtype: int64
#
# Uniformity of Cell Shape
#  1     89
# 10    18
# 3     14
# 4     12
# 2     12
# 6      8
# 5      8
# 8      7
# 7      6
# 9      1
# Name: Uniformity of Cell Shape, dtype: int64
#
# Marginal Adhesion
#  1     106
# 10     18
# 3      14
# 2      12
# 4       7
# 8       6
# 6       5
# 7       4
# 5       2
# 9       1
# Name: Marginal Adhesion, dtype: int64
#
# Single Epithelial Cell Size
#  2     100
# 3      16
# 4      13
# 10      9
# 6       9
# 1       9
# 8       8
# 5       8
# 7       2
# 9       1
# Name: Single Epithelial Cell Size, dtype: int64
#
# Bare Nuclei
#  1.000000     108
# 10.000000     34
# 2.000000       7
# ...

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

# %%
X_train = preprocessing.scale(X_train)
X_test = preprocessing.scale(X_test)
X_train.std(axis=0)
# Out:
# array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.,  1.,  1.])

# %%
lr = LogisticRegression()
sgdc = SGDClassifier()

# %%
lr.fit(X_train, Y_train)
lr_y_predict = lr.predict(X_test)

sgdc.fit(X_train, Y_train)
sgdc_y_predict = sgdc.predict(X_test)

# %%
from sklearn.metrics import classification_report
print("Logistic Regression Accuracy: ", lr.score(X_test, Y_test))
print(classification_report(Y_test, lr_y_predict, target_names=["Benign", "Malignant"]))
print("\nSGD Classifier Accuracy: ", sgdc.score(X_test, Y_test))
print(classification_report(Y_test, sgdc_y_predict, target_names=["Benign", "Malignant"]))
# Out:
# Logistic Regression Accuracy:  0.965714285714
#              precision    recall  f1-score   support
#
#      Benign       0.96      0.98      0.97       112
#   Malignant       0.97      0.94      0.95        63
#
# avg / total       0.97      0.97      0.97       175
#
#
# SGD Classifier Accuracy:  0.977142857143
#              precision    recall  f1-score   support
#
#      Benign       0.99      0.97      0.98       112
#   Malignant       0.95      0.98      0.97        63
#
# avg / total       0.98      0.98      0.98       175
